# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(context='talk', style='ticks',
        color_codes=True, rc={'legend.frameon': False})

# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.dpi'] = 300
plt.rcParams["font.family"] = 'Arial'
plt.rcParams.update({'font.size': 12})

fig,ax = plt.subplots()
fig.set_figheight(5)
fig.set_figwidth(5)
#ax.set_xlim([245,850])
#ax.set_ylim([0,105])
#ax.set_xticks(np.arange(250,851,150))
#ax.set_yticks(np.arange(20,101,20))
matplotlib.rcParams.update({'errorbar.capsize': 6})
plt.rcParams["font.family"] = 'Arial'
plt.rcParams.update({'font.size': 20})

colors = ['gold', 'goldenrod', 'firebrick']

plt.xticks([])
plt.ylabel('Exp-DB Test set RMSE \n (kcal/mol)')

#plt.scatter([0,1,2,3],   [0.600, 0.406, 0.434, 0.445],     
#color = colors[1], s=100, alpha=1.0, label = 'Exp-DB Valid. set')

plt.scatter([1,2,3],   [0.577, 0.549, 0.546], 
            color = 'navy', s=100, alpha=1.0, zorder=100)

plt.scatter([0],   [0.679], 
            color = '#1f77b4', s=100, alpha=.9, zorder=100, marker='D')

plt.scatter([4],   [0.586], 
            color = 'firebrick', s=100, alpha=.9, zorder=100, marker='s')


plt.errorbar([1,2,3],  [0.577, 0.549, 0.546], 
             yerr= [0.016, 0.023, 0.021], ls='none', color= 'navy')

plt.errorbar([4],  [ 0.586], 
             yerr= [0.015  ], ls='none', color= 'firebrick')


plt.errorbar([0],  [0.679], 
             yerr= [ 0.031], ls='none', color= '#1f77b4')


plt.plot([0,1,2,3],   [0.679, 0.577, 0.549, 0.546], '--',
            color = 'navy', alpha=.8, zorder=0)



#plt.scatter([0,1,2,3],   [0.596, 0.404, 0.432, 0.442],     color = colors[1], s=100, alpha=1.0, label = 'Exp-DB Valid. set')
#plt.errorbar([0,1,2,3],  [0.596, 0.404, 0.432, 0.442]   , yerr= [ 0.064, 0.045, 0.038, 0.036  ], ls='none', color= colors[1])
#plt.legend()
